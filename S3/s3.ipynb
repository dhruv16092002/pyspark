# %%
""" Config your configuration """
access_key = "Access_key"
secret_key = "secret_key"

hadoopConf=spark.sparkContext._jsc.hadoopConfiguration()
hadoopConf.set("fs.s3a.access.key", access_key)
hadoopConf.set("fs.s3a.secret.key", secret_key)

# %%
""" Read Dataframe """
df = spark.read.csv("s3a://<here s3 bucket name>/path/to/your/file.csv", header=True)

# %%
""" Between Transfromation of Dataframe """

# %%
df.write.csv("s3a://<here s3 bucket name>/path/to/your/file.csv", header=True, mode='overwrite')
